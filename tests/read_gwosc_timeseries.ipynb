# %%
import gwpy

# %%
start_time = 1187058327.1 -2
end_time = 1187058327.1 +2

kwargs = dict(source='/home/shunyin.cheung/amp_memory_GWTC3/tests/H-H1_GWOSC_O2_16KHZ_R1-1187057664-4096.hdf5', 
              path='/home/shunyin.cheung/amp_memory_GWTC3/tests/H-H1_GWOSC_O2_16KHZ_R1-1187057664-4096.hdf5',
              start=start_time, 
              end=end_time, 
              format="hdf5",)

data = gwpy.timeseries.TimeSeries.read(**kwargs)
data = data.crop(start=start_time, end=end_time)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/shunyin.cheung/amp_memory_GWTC3/tests/read_gwosc_timeseries.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226c6461732d7063646576362e6c69676f2e63616c746563682e656475222c2275736572223a227368756e79696e2e636865756e67227d/home/shunyin.cheung/amp_memory_GWTC3/tests/read_gwosc_timeseries.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> end_time = 1187058327.1 +2
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226c6461732d7063646576362e6c69676f2e63616c746563682e656475222c2275736572223a227368756e79696e2e636865756e67227d/home/shunyin.cheung/amp_memory_GWTC3/tests/read_gwosc_timeseries.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> kwargs = dict(source='/home/shunyin.cheung/amp_memory_GWTC3/tests/H-H1_GWOSC_O2_16KHZ_R1-1187057664-4096.hdf5',
# ...
